# %%
import pandas as pd
from data_concat import data_concat

data1 = pd.read_csv('./bitcoin_2022-04-14', encoding='utf-8')
data2 = pd.read_csv('./btc_2022-04-14', encoding='utf-8')
files = [data1,data2]
d_concat = data_concat()
d_concat.concat(files)
# Out:
#       number                       date              user_id  \
# 0          0  2022-04-13 23:59:29+00:00             26423172
# 1          1  2022-04-13 23:59:17+00:00            232487417
# 2          2  2022-04-13 23:59:04+00:00  1446844180102148098
# 3          3  2022-04-13 23:59:00+00:00            838829226
# 4          4  2022-04-13 23:58:31+00:00            366629301
# ...      ...                        ...                  ...
# 3669    3669  2022-04-13 03:25:59+00:00  1322880330098003970
# 3670    3670  2022-04-13 03:23:57+00:00  1379123235007123465
# 3671    3671  2022-04-13 03:22:33+00:00  1092770259680014336
# 3672    3672  2022-04-13 03:20:27+00:00  1465112803614892043
# 3673    3673  2022-04-13 03:17:25+00:00  1216703337317457921
#
#                                user_name user_screen_name  \
# 0                              Rob Leder           rleder
# 1                           Sadman Sakib         SakibS96
# ...

# %%
data1
# Out:
#       number                       date              user_id  \
# 0          0  2022-04-13 23:59:29+00:00             26423172
# 1          1  2022-04-13 23:59:17+00:00            232487417
# 2          2  2022-04-13 23:59:04+00:00  1446844180102148098
# 3          3  2022-04-13 23:59:00+00:00            838829226
# 4          4  2022-04-13 23:58:31+00:00            366629301
# ...      ...                        ...                  ...
# 5756    5756  2022-04-12 21:33:34+00:00            611493720
# 5757    5757  2022-04-12 21:32:48+00:00   956543009658671104
# 5758    5758  2022-04-12 21:32:24+00:00             19603980
# 5759    5759  2022-04-12 21:31:30+00:00             19777264
# 5760    5760  2022-04-12 21:31:19+00:00  1247744296008073223
#
#                                          user_name user_screen_name  \
# 0                                        Rob Leder           rleder
# 1                                     Sadman Sakib         SakibS96
# ...

# %%
data2
# Out:
#       number                       date              user_id  \
# 0          0  2022-04-13 23:59:59+00:00  1354497021860859906
# 1          1  2022-04-13 23:59:55+00:00  1319937348344315905
# 2          2  2022-04-13 23:59:53+00:00             22448465
# 3          3  2022-04-13 23:58:59+00:00  1390718060680581124
# 4          4  2022-04-13 23:58:19+00:00   867402323747799041
# ...      ...                        ...                  ...
# 3669    3669  2022-04-13 03:25:59+00:00  1322880330098003970
# 3670    3670  2022-04-13 03:23:57+00:00  1379123235007123465
# 3671    3671  2022-04-13 03:22:33+00:00  1092770259680014336
# 3672    3672  2022-04-13 03:20:27+00:00  1465112803614892043
# 3673    3673  2022-04-13 03:17:25+00:00  1216703337317457921
#
#                     user_name user_screen_name  \
# 0                coindicators     coindicators
# 1         会長@IOST&NXDホールディングス         IOST_210
# 2                     Tan 🌖🧪⚛         tan_twtt
# ...

# %%
d_concat.save_csv("Bit_coin")

# %%
concat_data = pd.read_csv('./Bit_coin.csv', encoding='utf-8')

# %%
concat_data = concat_data.drop('Unnamed: 0', axis=1)

# %%
concat_data
# Out:
#       number                       date              user_id  \
# 0          0  2022-04-13 23:59:29+00:00             26423172
# 1          1  2022-04-13 23:59:17+00:00            232487417
# 2          2  2022-04-13 23:59:04+00:00  1446844180102148098
# 3          3  2022-04-13 23:59:00+00:00            838829226
# 4          4  2022-04-13 23:58:31+00:00            366629301
# ...      ...                        ...                  ...
# 9430    3669  2022-04-13 03:25:59+00:00  1322880330098003970
# 9431    3670  2022-04-13 03:23:57+00:00  1379123235007123465
# 9432    3671  2022-04-13 03:22:33+00:00  1092770259680014336
# 9433    3672  2022-04-13 03:20:27+00:00  1465112803614892043
# 9434    3673  2022-04-13 03:17:25+00:00  1216703337317457921
#
#                                user_name user_screen_name  \
# 0                              Rob Leder           rleder
# 1                           Sadman Sakib         SakibS96
# ...
